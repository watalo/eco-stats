# %%
## 读取stata文件
import pandas as pd

df = pd.read_stata('../Econometrics_CQ/2_Data/Data-2e/basque.dta')
df.head()
# Out:
#    regionno      regionname    year    gdpcap  sec_agriculture  sec_energy  \
# 0       1.0  Spain (Espana)  1955.0  2.354542              NaN         NaN
# 1       1.0  Spain (Espana)  1956.0  2.480149              NaN         NaN
# 2       1.0  Spain (Espana)  1957.0  2.603613              NaN         NaN
# 3       1.0  Spain (Espana)  1958.0  2.637104              NaN         NaN
# 4       1.0  Spain (Espana)  1959.0  2.669880              NaN         NaN
#
#    sec_industry  sec_construction  sec_services_venta  sec_services_nonventa  \
# 0           NaN               NaN                 NaN                    NaN
# 1           NaN               NaN                 NaN                    NaN
# 2           NaN               NaN                 NaN                    NaN
# 3           NaN               NaN                 NaN                    NaN
# 4           NaN               NaN                 NaN                    NaN
#
# ...
